# %%
import json
import pandas as pd
import itertools
from collections import Counter

# %%
train = pd.read_json('../file/train.json', encoding='utf-8')

# %%
validation = pd.read_json('../file/val.json', encoding='utf-8')

# %%
song_meta = pd.read_json('../file/song_meta.json', encoding='utf-8')

# %%
with open('../file/genre_gn_all.json', encoding='utf-8') as f:
    genre = json.load(f)

# %%
genre = {key: (genre[key[:-1]+'0'] if key[-2:] =='01' else value) for key, value in genre.items()}

# %%
song_meta['genre_list'] = song_meta.song_gn_dtl_gnr_basket

# %%
song_meta['song_gn_word'] = song_meta.genre_list.apply(lambda e: list(map(lambda x: genre[x], filter(lambda y: y in genre, e))))

# %%
song_meta['song_gn_word_split'] = song_meta.song_gn_word.apply(lambda e: list(itertools.chain(*map(lambda x: x.split('/'), e))))

# %%
song_meta_dropna = song_meta.dropna(subset=['song_gn_word_split'])

# %%
song_id_genre = dict(zip(song_meta_dropna['id'], song_meta_dropna['song_gn_word_split']))

# %%
genre_count = dict(Counter([__ for _ in song_meta.song_gn_word_split for __ in _]))

# %%
tag_count = Counter([__ for _ in train.tags for __ in _])

# %%
print('태그 내에 들어있는 장르 이름들 :', set(tag_count).intersection(genre_count))
# Out:
# 태그 내에 들어있는 장르 이름들 : {'소울', '뉴에이지', '하드코어랩', '뮤직테라피', '국내영화', '얼터너티브힙합', '컨트리', '모던록', '집중력', '보사노바', '사물놀이', '레게', '월드팝', '댄스', '탱고', '시부야케이', '워십', '록', '자연', 'CCM', '기타', '국외영화', '판소리', '클럽', '재즈', '블루스', '국악가요', '아이돌', '기능성음악', '하드코어', '합창곡', '힐링', '라틴재즈', '스윙', '어린이', '교향곡', '성악', '어반', '민요', '팝랩', '성인가요', '애니메이션', '월드뮤직', '불교', '국악', '컴필레이션', '요가', '힙합', '피아노', '브라질', '팝', 'DJ', '이지리스닝', '반려동물', '만화', '국외뮤지컬', '일렉트로니카', '아트록', '뉴메탈', '연주곡', '파두', '플라멩코', '갱스터', '관현악', '국내드라마', '찬송가', 'EDM', '일렉', '라틴', '현대음악', '샹송', '오페라', '중국음악', '올디스', '클래식', '영어동화', '무용', '애시드', '랩', '어린이클래식', '프로그레시브', '명상', '클럽뮤직', '헤비메탈', '보컬재즈', '프렌치팝', '하우스', '메탈', '인디음악', '숙면유도', '협주곡', '독주곡', '뮤지컬', '발레', '태교', '창작동요', '퓨전', '교과서동요', '얼터너티브록', '자장가', '포스트록', 'OST', '게임', '국외드라마', '실내악', '켈틱', '웹툰', '포크', '성가', '일렉트로닉팝', '칸초네', '종교음악', '크로스오버', '하드록', '얼터너티브팝', '발라드', '전래동요', '빅밴드', 'ASMR', '영어동요'}

# %%
train['genre'] = train.songs.apply(lambda e: Counter(itertools.chain(*list(map(lambda x: song_id_genre[x], e)))).most_common())

# %%
train.head(1)
# Out:
#       id  like_cnt plylst_title  \
# 0  61281        71      여행같은 음악
#
#                                                songs tags  \
# 0  [525514, 129701, 383374, 562083, 297861, 13954...  [락]
#
#                  updt_date                                              genre
# 0  2013-12-19 18:36:19.000  [(POP, 10), (록, 10), (메탈, 10), (포크, 6), (얼터너티브...

# %%
pd.options.display.max_colwidth = 1000

# %%
train[['genre', 'tags']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                      genre  \
# 0                                                                                                                                                                                       [(POP, 10), (록, 10), (메탈, 10), (포크, 6), (얼터너티브팝, 5), ('00, 4), (블루스, 3), (컨트리, 3), (일렉트로니카, 3), (얼터너티브록, 2), ('90, 1), (하드록, 1), (어반, 1), (R&B, 1), (Soul, 1), (컨템포러리 R&B, 1), (월드팝, 1), ('00-'10, 1), (J-POP, 1)]
# 1                                                                                                                                  [(록, 16), ('10-, 16), (발라드, 11), (메탈, 11), ('00, 10), (인디음악, 7), (재즈, 7), (포크, 4), (J-Jazz, 4), (크로스오버, 4), (클래식, 4), (OST, 4), (J-Newage, 3), (뉴에이지, 3), (국내드라마, 3), (빅밴드, 3), (스윙, 3), (블루스, 2), ('90, 1), (일렉트로니카, 1), (팝 스타일, 1), (댄스 스타일, 1), (국내영화, 1), (POP, 1)]
# 2                                                                                                                                                                                               [(R&B, 25), ('10-, 18), (Soul, 15), (인디음악, 12), (록, 8), (메탈, 4), (보컬 스타일, 3), (랩, 3), (힙합, 3), (포크, 3), (발라드, 2), (블루스, 2), (어반, 1), (재즈, 1), (애시드, 1), (퓨전, 1), (팝, 1), (일렉트로니카, 1), (팝 스타일, 1), (일렉, 1)]
# 3                                                                               [('10-, 20), (발라드, 17), (인디음악, 8), (록, 8), (애니메이션, 6), (재즈, 6), (POP, 5), (OST, 5), (R&B, 5), (Soul, 5), (컨템포러리 R&B, 5), (메탈, 4), (웹툰, 3), (만화, 3), (게임, 3), (포크, 3), (J-Jazz, 2), (국내드라마, 2), (블루스, 2), ('90, 1), ('00, 1), (J-Newage, 1), (뉴에이지, 1), (보컬재즈, 1), (빅밴드, 1), (스윙, 1), (신세대트로트, 1), (트로트'00-, 1), (성인가요, 1)]
# 4                                                                                                                                                                                                                                           [(댄스, 55), ('90, 34), (아이돌, 15), (남자 아이돌, 8), ('00, 8), (여자 아이돌, 7), (발라드, 6), (랩, 5), (힙합, 5), (보컬 스타일, 3), (R&B, 2), (Soul, 1), (랩 스타일, 1), (록, 1), (메탈, 1)]
# 5                                                                                                                                                                                                          [(일렉트로니카, 19), (클럽뮤직, 11), (POP, 7), (하우스, 6), (DJ, 4), (랩, 3), (힙합, 3), (일렉트로닉팝, 3), (R&B, 2), (Soul, 2), (컨템포러리 R&B, 2), (어반, 1), (얼터너티브팝, 1), (록, 1), (메탈, 1), (국외영화, 1), (OST, 1), (클럽, 1)]
# 6                                                                                                                                                                                                                                              [(발라드, 33), ('10-, 29), (R&B, 8), (OST, 8), (국내드라마, 8), ('00, 8), (포크, 6), (인디음악, 5), (Soul, 4), (록, 4), (블루스, 3), (남자 아이돌, 3), (아이돌, 3), (메탈, 2), (어반, 1)]
# 7                                                                                                                                                                                                                                   [(발라드, 12), ('00, 11), (록, 3), (메탈, 3), (댄스, 3), (아이돌, 2), (보컬 스타일, 2), (랩, 2), (힙합, 2), (R&B, 2), (남자 아이돌, 1), (여자 아이돌, 1), (Soul, 1), (국내영화, 1), (OST, 1), ('90, 1)]
# 8                                                                                                                                                                                                                      [(댄스, 31), ('10-, 22), ('00, 11), (록, 10), (메탈, 10), (아이돌, 8), (발라드, 5), (남자 아이돌, 4), (여자 아이돌, 4), (성인가요, 1), (일렉트로니카, 1), (팝 스타일, 1), (댄스 스타일, 1), (OST, 1), (국내드라마, 1), ('90, 1)]
# 9                                                                                                                                                                                                                                                                                                                                                     [(록, 20), ('10-, 16), (메탈, 15), (인디음악, 5), ('00, 4)]
# 10                                                                                                                                                                                                                                                                     [(댄스, 288), (아이돌, 151), (여자 아이돌, 149), ('10-, 140), (랩, 14), (힙합, 14), ('00, 3), (R&B, 3), (보컬 스타일, 2), (Soul, 2), (록, 1), (메탈, 1)]
# 11                                                                                                                                                                              [('10-, 28), (발라드, 18), (록, 17), (인디음악, 14), ('00, 12), (힙합, 10), (메탈, 9), (랩, 8), (포크, 8), (댄스, 8), (OST, 5), (블루스, 4), (국내드라마, 4), (보컬 스타일, 4), (아이돌, 3), (언더그라운드 힙합, 2), (남자 아이돌, 2), (여자 아이돌, 1), (국내영화, 1), ('90, 1)]
# 12                                                                                                                                                [('10-, 13), (발라드, 11), ('00, 4), (포크, 4), (R&B, 3), (댄스, 3), (인디음악, 3), (Soul, 2), (블루스, 2), (신세대트로트, 1), (전설의트로트, 1), (트로트'00-, 1), (성인가요, 1), (록, 1), (메탈, 1), (여자 아이돌, 1), (아이돌, 1), (보컬 스타일, 1), (랩, 1), (힙합, 1), (일렉트로니카, 1), (팝 스타일, 1), (일렉, 1)]
# 13                                                                                                                                                                         [(힙합, 56), (랩, 46), (보컬 스타일, 33), (R&B, 31), (Soul, 19), (인디음악, 12), (언더그라운드 힙합, 10), (어반, 7), (아이돌, 6), (남자 아이돌, 5), (댄스, 4), ('10-, 4), (일렉트로니카, 2), (컨템포러리 R&B, 1), (포크, 1), (블루스, 1), (팝 스타일, 1), (일렉트로닉팝, 1), (여자 아이돌, 1)]
# 14                                                                                                                                                                                                                                                         [(재즈, 33), (보컬재즈, 10), (애시드, 4), (퓨전, 4), (팝, 4), (브라질, 2), (월드뮤직, 2), (라틴재즈, 1), (J-Jazz, 1), (POP, 1), (기타, 1), (뉴에이지, 1), (빅밴드, 1), (스윙, 1)]
# 15                                                                                                                                                             [(록, 22), (메탈, 22), ('00, 15), (POP, 9), (R&B, 9), (Soul, 9), (컨템포러리 R&B, 8), (일렉트로니카, 8), (얼터너티브록, 5), (헤비메탈, 5), (클럽뮤직, 5), (어반, 4), (얼터너티브팝, 3), (DJ, 3), (OST, 3), (하우스, 2), ('90, 2), (국외영화, 2), (랩, 1), (힙합, 1), (뉴메탈, 1), (하드코어, 1)]
# 16                                                                                                                                                           [(POP, 12), (일렉트로니카, 11), (R&B, 6), (Soul, 6), (컨템포러리 R&B, 5), (DJ, 5), (록, 4), (메탈, 4), (랩, 3), (힙합, 3), ('00, 2), (포크, 2), (얼터너티브팝, 2), (클럽뮤직, 2), (어반, 2), (블루스, 1), (컨트리, 1), (하우스, 1), ('10-, 1), (국외영화, 1), (OST, 1), (소울, 1), (팝랩, 1)]
# 17                                                                                                                                                                                                                                                                           [(발라드, 7), ('10-, 5), (아이돌, 2), (댄스, 2), (여자 아이돌, 1), (OST, 1), (국내드라마, 1), ('90, 1), (보컬 스타일, 1), (랩, 1), (힙합, 1), ('00, 1)]
# 18                                                                                                                                                                                                                                                               [('10-, 15), (발라드, 12), (포크, 7), (블루스, 4), (인디음악, 4), (OST, 4), ('00, 4), (국내드라마, 3), (국내뮤지컬, 2), (보컬 스타일, 1), (랩, 1), (힙합, 1), (뮤지컬, 1)]
# 19                                                                                                                                                                                                                                                                                            [(댄스, 19), (남자 아이돌, 15), (아이돌, 15), ('10-, 10), (발라드, 8), (랩, 2), (힙합, 2), (보컬 스타일, 1), (R&B, 1), (Soul, 1)]
# 20                                                                                                    [('10-, 33), (발라드, 25), (OST, 11), (국내드라마, 11), (R&B, 10), (인디음악, 8), (포크, 7), (힙합, 6), (블루스, 5), (Soul, 5), (아이돌, 4), (록, 4), (보컬 스타일, 4), (랩, 4), (여자 아이돌, 3), (일렉트로니카, 3), (메탈, 3), (뉴에이지, 3), (팝 스타일, 2), (피아노, 2), (언더그라운드 힙합, 2), (POP, 1), (시부야케이, 1), ('00-'10, 1), (J-POP, 1), (남자 아이돌, 1)]
# 21                                                                                                                                                                                                                                                                                                                                   [(재즈, 13), (애시드, 6), (퓨전, 6), (팝, 6), (보컬재즈, 5), ('10-, 1), (POP, 1)]
# 22                                                                                                                                                                                                                                                                                                                                                                       [(국외영화, 13), (OST, 13), (POP, 5)]
# 23                                                                                                                                                                                                                               [('00, 21), (댄스, 16), (발라드, 10), (보컬 스타일, 6), (랩, 6), (힙합, 6), (아이돌, 4), (OST, 3), (여자 아이돌, 2), (남자 아이돌, 2), (국내드라마, 2), (국내영화, 1), (록, 1), (메탈, 1), (R&B, 1), (Soul, 1)]
# 24                                                                                                                                                                                                                                                                                                                                [('10-, 36), (포크, 24), (인디음악, 19), (블루스, 12), (록, 8), (발라드, 7), (메탈, 4)]
# 25                                 [(록, 13), (메탈, 13), (일렉트로니카, 10), (R&B, 9), (Soul, 9), (컨템포러리 R&B, 8), ('00, 7), (재즈, 7), (어반, 6), (랩, 5), (힙합, 5), (Bop, 5), (POP, 3), (OST, 3), (프로그레시브, 2), (아트록, 2), (갱스터, 2), (하드코어랩, 2), (East&West, 2), (일렉트로닉팝, 2), ('80-'90, 2), (국외영화, 2), (포스트록, 2), (팝랩, 1), ('90, 1), ('70, 1), (얼터너티브힙합, 1), (애니메이션, 1), (웹툰, 1), (애시드, 1), (퓨전, 1), (팝, 1), (얼터너티브팝, 1)]
# 26                                                                                                       [('10-, 45), (록, 28), (인디음악, 25), (발라드, 24), ('00, 21), (포크, 21), (메탈, 16), (R&B, 12), (블루스, 11), (Soul, 7), (OST, 5), (보컬 스타일, 5), (랩, 5), (힙합, 5), (국내영화, 3), (어반, 3), (댄스, 3), (아이돌, 2), (일렉트로니카, 2), (팝 스타일, 2), (여자 아이돌, 1), (재즈, 1), (국내드라마, 1), (일렉, 1), (애니메이션, 1), (게임, 1), (남자 아이돌, 1)]
# 27                                                                                                                                                                     [(발라드, 71), ('10-, 60), (OST, 20), (국내드라마, 18), (댄스, 17), (R&B, 14), (보컬 스타일, 13), (아이돌, 10), (인디음악, 10), (포크, 10), (랩, 10), (힙합, 10), (블루스, 7), (Soul, 7), ('00, 7), (록, 5), (메탈, 3), (여자 아이돌, 3), (남자 아이돌, 3), (어반, 1), ('90, 1)]
# 28                                                                                                                                                                                                                                                                                                                                        [(발라드, 18), ('00, 13), ('10-, 5), (댄스, 3), (OST, 2), (국내드라마, 2)]
# 29                                                                                                                                                                                                                                                                                                                                [(힙합, 52), (랩, 29), ('10-, 23), (언더그라운드 힙합, 23), (인디음악, 23), (랩 스타일, 6)]
# ...                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 115041                                                                                                                                 [(댄스, 44), (아이돌, 27), ('10-, 26), (힙합, 25), (랩, 24), (보컬 스타일, 14), (여자 아이돌, 13), (남자 아이돌, 13), (POP, 13), (R&B, 9), (Soul, 6), (일렉트로니카, 5), (어반, 4), (록, 4), (메탈, 4), ('00, 4), (인디음악, 2), (얼터너티브팝, 2), (포크, 2), (언더그라운드 힙합, 1), (DJ, 1), (블루스, 1), (컨템포러리 R&B, 1)]
# 115042                                                                                                                                                                                                                   [('00, 8), (OST, 5), (발라드, 5), (록, 5), (메탈, 4), (랩, 2), (힙합, 2), (국내드라마, 2), (일렉트로니카, 2), (팝 스타일, 2), (랩 스타일, 1), (만화, 1), (애니메이션, 1), (웹툰, 1), (보컬 스타일, 1), (POP, 1), (인디음악, 1)]
# 115043                                                                                                                                                                                                                                                                                                                               [(재즈, 14), (J-Jazz, 8), (일렉트로니카, 4), (컴필레이션, 2), (클럽뮤직, 2), (Bop, 1)]
# 115044                                                                                                                                                [(발라드, 40), ('10-, 24), (아이돌, 12), (댄스, 12), (여자 아이돌, 10), ('00, 9), (랩, 7), (힙합, 7), (보컬 스타일, 4), (OST, 4), ('90, 3), (록, 3), (국내드라마, 3), (R&B, 2), (남자 아이돌, 2), (메탈, 2), (Soul, 1), (어반, 1), (인디음악, 1), (포크, 1), (블루스, 1), (국외영화, 1), (얼터너티브팝, 1)]
# 115045                                                                                                            [('10-, 18), (록, 12), (포크, 11), (인디음악, 10), (메탈, 8), ('00, 7), (블루스, 6), (발라드, 6), (R&B, 6), (Soul, 4), (관현악, 4), (헤비메탈, 3), (POP, 2), (클래식, 2), (교향, 2), (컨트리, 2), (일렉트로니카, 1), (댄스 스타일, 1), (일렉, 1), (보컬 스타일, 1), (랩, 1), (힙합, 1), (여자 아이돌, 1), (아이돌, 1), (재즈, 1), (댄스, 1), (성인가요, 1)]
# 115046                                                                                                                                                                                                                                                                                                         [(J-POP, 26), ('00-'10, 24), (POP, 17), (록, 8), ('80-'90, 2), (R&B, 2), (힙합, 1), (Soul, 1)]
# 115047                                                                                                                                                                                                                                                                                [(발라드, 25), ('00, 12), (아이돌, 12), (남자 아이돌, 7), (R&B, 6), (여자 아이돌, 5), ('90, 4), (Soul, 3), (랩, 1), (힙합, 1), (댄스, 1)]
# 115048                                                                                                                                                                                                                                                            [(랩, 11), (힙합, 11), ('00, 7), (팝랩, 5), (갱스터, 2), (하드코어랩, 2), (East&West, 2), (남자 아이돌, 1), (아이돌, 1), (R&B, 1), (Soul, 1), (컨템포러리 R&B, 1)]
# 115049                                                                                                                                                                                      [('10-, 19), (발라드, 13), (댄스, 5), (포크, 5), (OST, 5), (인디음악, 5), (록, 4), (아이돌, 3), (블루스, 3), (국내드라마, 3), (남자 아이돌, 2), (메탈, 2), ('00, 2), (R&B, 2), (일렉트로니카, 1), (팝 스타일, 1), (일렉, 1), (Soul, 1), (랩, 1), (힙합, 1)]
# 115050                                                                                                                                                                                                                                                             [(힙합, 19), (랩, 16), (보컬 스타일, 6), (인디음악, 4), (언더그라운드 힙합, 3), (랩 스타일, 2), (댄스, 2), ('00, 1), (일렉트로니카, 1), (팝 스타일, 1), (일렉, 1), ('10-, 1)]
# 115051                                                                                                                                                                   [(포크, 15), (POP, 15), (록, 13), (메탈, 13), ('00, 13), (컨트리, 11), (블루스, 10), (얼터너티브팝, 5), (R&B, 4), (Soul, 4), (컨템포러리 R&B, 4), (국외영화, 3), (OST, 3), ('00-'10, 3), (J-POP, 3), ('90, 2), ('80-'90, 2), ('00-, 2), (하드록, 1), ('60, 1)]
# 115052                                                                                                                                                                                 [(POP, 12), ('00, 4), (록, 4), (메탈, 4), (컴필레이션, 3), (올디스, 2), (클래식, 2), (오페라, 2), (관현악, 2), (어반, 2), (R&B, 2), (Soul, 2), (재즈, 1), (보컬재즈, 1), (발라드, 1), (이지리스닝, 1), (뉴에이지, 1), (성인가요, 1), (성악, 1), (교향, 1), (소울, 1)]
# 115053                                                                                                                                                                                                                                                                                                                                                       [(일렉트로니카, 19), (클럽뮤직, 11), (하우스, 4), (DJ, 2)]
# 115054                                                                                                                                                                                                                                                                                               [(POP, 18), (컨템포러리 R&B, 11), (R&B, 10), (Soul, 10), ('00, 5), (어반, 4), (월드팝, 2), (국외영화, 1), (OST, 1)]
# 115055                                                                                                                                              [('10-, 38), (발라드, 35), (록, 7), (포크, 6), (R&B, 6), (메탈, 5), (인디음악, 5), (블루스, 4), ('00, 4), (힙합, 3), (Soul, 3), (OST, 2), (국내드라마, 2), (랩, 2), ('90, 2), (기타, 1), (뉴에이지, 1), (언더그라운드 힙합, 1), (랩 스타일, 1), ('80, 1), (신세대트로트, 1), (트로트'00-, 1), (성인가요, 1)]
# 115056                                                                                                                                                                                        [(힙합, 60), (랩, 46), (보컬 스타일, 32), (R&B, 17), (인디음악, 14), (언더그라운드 힙합, 14), (Soul, 10), (어반, 6), ('10-, 4), (아이돌, 4), (발라드, 3), (남자 아이돌, 2), (여자 아이돌, 2), (OST, 1), (국내드라마, 1), (포크, 1), (블루스, 1), (랩 스타일, 1)]
# 115057                                                                                                                                                                                                                                                                                                                            [('10-, 32), (포크, 28), (블루스, 16), (인디음악, 16), (록, 6), (메탈, 3), (발라드, 3)]
# 115058                                                                                                                                                                                                                                                                                                                      [(댄스, 39), (여자 아이돌, 22), ('10-, 22), (아이돌, 22), (발라드, 6), (국내영화, 1), (OST, 1)]
# 115059                                                                                                                                       [('10-, 54), (발라드, 31), (포크, 26), (인디음악, 18), (블루스, 13), (댄스, 13), (랩, 12), (힙합, 12), (R&B, 12), (록, 12), (아이돌, 11), (보컬 스타일, 10), (남자 아이돌, 8), (메탈, 7), (Soul, 6), ('00, 5), (여자 아이돌, 3), (OST, 3), (국내드라마, 3), ('90, 3), (어반, 2), (일렉트로니카, 1), (댄스 스타일, 1)]
# 115060                                                                                                                                                                                                                                                                                                                   [(하우스, 82), (EDM, 52), (클럽, 47), ('10-, 12), (일렉트로니카, 11), (일렉트로닉팝, 5), (POP, 5)]
# 115061                                                                                          [('10-, 66), (발라드, 42), (록, 38), (인디음악, 28), (포크, 27), (메탈, 26), ('00, 23), (R&B, 22), (블루스, 16), (Soul, 15), (POP, 10), (OST, 8), (컨템포러리 R&B, 8), (국내드라마, 5), ('90, 4), (댄스, 3), (어반, 3), (국외영화, 2), (랩, 2), (힙합, 2), (얼터너티브팝, 2), (소울, 1), (보컬 스타일, 1), (일렉트로니카, 1), (팝 스타일, 1), (댄스 스타일, 1), (헤비메탈, 1)]
# 115062                                                                                                                                                                                                                                                 [(J-POP, 99), ('00-'10, 96), (록, 56), (POP, 39), (OST, 2), (애니메이션, 2), (시부야케이, 2), (일렉트로니카, 2), (게임, 1), (웹툰, 1), ('80-'90, 1), (재즈, 1), (국외영화, 1)]
# 115063                                                                                                                                                                             [(OST, 26), (국내드라마, 22), (발라드, 21), ('10-, 18), ('00, 6), (포크, 6), (록, 5), (아이돌, 5), (블루스, 5), (메탈, 4), (여자 아이돌, 4), (댄스, 3), (인디음악, 3), ('90, 2), (국내영화, 2), (일렉트로니카, 1), (팝 스타일, 1), (일렉, 1), (국외영화, 1), (남자 아이돌, 1)]
# 115064                                                                                                                                                  [(R&B, 5), ('00, 3), (POP, 3), (록, 3), (메탈, 3), (Soul, 3), ('00-'10, 3), (J-POP, 3), (OST, 3), (얼터너티브팝, 2), (힙합, 2), (애니메이션, 2), (발라드, 2), (포크, 1), (블루스, 1), (게임, 1), (웹툰, 1), (국외영화, 1), (클럽뮤직, 1), (일렉트로니카, 1), ('10-, 1), (국내드라마, 1), (어반, 1)]
# 115065                                                                                                                                                                                                                                                                                                 [(발라드, 13), (R&B, 8), ('10-, 5), (Soul, 4), ('00, 4), (록, 1), (메탈, 1), ('90, 1), (포크, 1), (블루스, 1)]
# 115066                                                                                                                                                                                                                                                                                         [(록, 11), (메탈, 11), ('00, 6), (뉴메탈, 6), (하드코어, 6), (헤비메탈, 3), (프로그레시브, 2), (아트록, 2), ('90, 1), (일렉트로니카, 1)]
# 115067                                                                                                                                                                                                                                                                                                                                                                [(일렉트로니카, 14), (클럽뮤직, 11), (하우스, 3)]
# 115068                                                                                                                                                                                                                                                                                  [(발라드, 8), ('10-, 6), ('00, 3), (록, 2), (메탈, 2), (R&B, 2), (남자 아이돌, 1), (아이돌, 1), (Soul, 1), (OST, 1), (국내드라마, 1)]
# 115069                                                                                                                 [(록, 25), (메탈, 25), (포크, 19), (POP, 15), (컨트리, 11), (얼터너티브팝, 10), (블루스, 10), (일렉트로니카, 8), (얼터너티브록, 4), (월드뮤직, 4), ('00, 3), (포스트록, 3), (국외영화, 2), (OST, 2), (랩, 2), (힙합, 2), ('10-, 2), ('90, 1), (갱스터, 1), (하드코어랩, 1), (얼터너티브힙합, 1), (R&B, 1), (Soul, 1), (컨템포러리 R&B, 1), (팝랩, 1)]
# 115070  [(록, 91), (메탈, 91), (POP, 86), (포크, 49), ('00, 37), (얼터너티브팝, 37), (컨트리, 32), (블루스, 27), (OST, 22), (국외영화, 20), (얼터너티브록, 15), ('90, 8), (하드록, 7), (R&B, 7), (Soul, 7), (모던록, 6), (일렉트로니카, 5), (컨템포러리 R&B, 4), (랩, 3), (힙합, 3), (팝랩, 3), (어반, 3), ('00-, 2), (클럽뮤직, 2), ('10-, 2), (애니메이션, 2), (포스트록, 1), ('70, 1), ('80, 1), (프로그레시브, 1), (아트록, 1), (국내드라마, 1), (소울, 1), (DJ, 1), (게임, 1), (웹툰, 1)]
#
#                                                                 tags
# 0                                                                [락]
# 1                                                           [추억, 회상]
# 2                                                          [까페, 잔잔한]
# 3       [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스, 겨울왕국, 크리스마스송]
# 4                                                               [댄스]
# 5               [운동, 드라이브, Pop, 트로피컬하우스, 힐링, 기분전환, 2017, 팝, 트렌드, 일렉]
# 6                                        [짝사랑, 취향저격, 슬픔, 고백, 사랑, 이별]
# 7                                                      [잔잔한, 추억, 회상]
# 8                                        [일렉트로니카, 포크, 메탈, 락, 댄스, 인디]
# 9                                 [록, Metal, 이일우, M에센셜, 메탈, Rock, 락]
# 10                                         [kpop, 댄스, 걸그룹댄스, 스트레스해소]
# 11                  [새해, 여행, 프로필음악, 카카오톡, 기분전환, 소원, 프로필, 소망, 다짐, 카톡]
# 12                                              [듣고, 우울, 힐링, 이거, 힘내]
# 13                      [힙합, 느낌있는, 밤, 새벽, RnB, 감각적인, 드라이브, 국내, 그루브한]
# 14                                                          [가을, 재즈]
# 15                                                               [락]
# 16                                          [감성, 질리지않는, 나만알고싶은, Pop]
# 17                                                       [봄, 설렘, 사랑]
# 18                                                   [비오는날, 누군가생각날때]
# 19                                            [스밍, 목록, 폐막식, 올림픽, 엑소]
# 20                                     [조용히, 혼자, 또는, 새벽감성, 고민, 맥주한잔]
# 21                                                     [카페, 재즈, 잔잔한]
# 22                                                             [OST]
# 23                                                              [댄스]
# 24                                   [감성, 어쿠스틱, 잔잔한, 새벽, 편안한, 인디, 밤]
# 25                                                      [잔잔한, 밤, 새벽]
# 26                                           [힐링, 드라이브, 에너지, 인디, 여행]
# 27                                       [듀엣, 취향저격, 달달, 피쳐링, 사랑, 남녀]
# 28                                                      [까페, 설렘, 사랑]
# 29                                             [힙합, 신인, 국힙, 인디, 신나는]
# ...                                                              ...
# 115041                                [아침, 운동, 드라이브, 힐링, 기분전환, 스트레칭]
# 115042                                                       [밤, 새벽]
# 115043                                       [재즈, 드라이브, 파티, 빅밴드, 스윙]
# 115044                                                [휴식, 힐링, 기분전환]
# 115045                                                     [이별, 그리움]
# 115046                                                        [JPOP]
# 115047                                                  [부들부들, 감미로운]
# 115048                                                       [힙합, 랩]
# 115049                                                  [겨울, 설렘, 사랑]
# 115050                                                       [힙합, 랩]
# 115051                                                           [락]
# 115052                                              [슬픔, 이별, 설렘, 사랑]
# 115053                  [클럽, 홍대, 운동, 열정, EDM, 20대, 라운지, 월디페, 느낌, 일렉]
# 115054                                                           [팝]
# 115055                                                    [매장음악, 까페]
# 115056                         [힙합, 감성힙합, 봄, 알앤비, 매장, 그루브, 휴식, 기분전환]
# 115057                                                          [인디]
# 115058                                                          [여친]
# 115059                                               [사랑, 밤, 설렘, 새벽]
# 115060         [일렉트로니카, 운동, 에너지, 드라이브, EDM, 기분전환, 파티, 기분업, 하우스, 신나는]
# 115061                                                          [까페]
# 115062                                                [힐링, 휴식, 기분전환]
# 115063                                            [드라마, 설렘, OST, 센치]
# 115064                                                        [JPOP]
# 115065                                                      [설렘, 사랑]
# 115066                          [록메탈, 밴드사운드, 록, 락메탈, 메탈, 락, extreme]
# 115067                                                          [일렉]
# 115068                        [담시, 가족, 눈물, 그리움, 주인공, 나의_이야기, 사랑, 친구]
# 115069                                 [잔잔한, 버스, 퇴근버스, Pop, 풍경, 퇴근길]
# 115070                                        [노래추천, 팝송추천, 팝송, 팝송모음]
#
# [115071 rows x 2 columns]
